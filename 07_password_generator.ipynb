# %%
import random
import string

chars = string.ascii_letters + string.digits + string.punctuation

password_length = int(input('Enter the length of the password: '))
number_of_passwords = int(input('Enter the number of passwords to generate: '))

for i in range(number_of_passwords):
    password = ''
    for j in range(password_length):
        password += random.choice(chars)
    print(f'Password {i+1}: {password}')
# Out:
# Enter the length of the password: 16
# Enter the number of passwords to generate: 10
# Password 1: R^;wyuQ*dz0ff@Oo
# Password 2: JV>}3hxs~en(A/[3
# Password 3: CNJZGbOo#wdg{)?,
# Password 4: /ai-hk?9aY+n8@3v
# Password 5: )'.C:DA]X^yH3Omp
# Password 6: caNGZ.&XBUuP`nB{
# Password 7: .yV$0'>V1.)8Ps;d
# Password 8: ;]M1h{e;~)=FO[{8
# Password 9: a'O4v`TJ`l>l/e1J
# Password 10: -Ua\yC0]^aVwuG`9

# %%
1
