# %%
import time

def countdown_timer():
  t : int = int(input("Enter time in seconds: "))

  while(t):
    min, secs = divmod(t, 60)
    print(f"{min:02d}:{secs:02d}")
    time.sleep(1)
    t -= 1
  print("Time's up")

countdown_timer()
# Out:
# Enter time in seconds: 5
# 00:05
# 00:04
# 00:03
# 00:02
# 00:01
# Time's up
